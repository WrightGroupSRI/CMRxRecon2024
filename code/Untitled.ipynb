# %%
from cmrxrecon.dl.AllContrastDataModule import AllContrastDataModule, ZeroPadKSpace, NormalizeKSpace
from cmrxrecon.dl.dataloaders.AllContrastDataset import AllContrastDataset
from torchvision.transforms import Compose

# %%
 data_module = AllContrastDataModule(data_dir='/home/kadotab/scratch/MICCAIChallenge2024/ChallengeData/MultiCoil/',
                                     batch_size=1)

# %%
all_contrast_full = AllContrastDataset(
                '/home/kadotab/scratch/MICCAIChallenge2024/ChallengeData/MultiCoil/', 
                train=True,
                task_one=False,
                transforms=Compose([NormalizeKSpace(), ZeroPadKSpace()])
                )
# Out:
# Counting Slices in cine_lvot
# Found 193 slices!
# Counting Slices in cine_lax
# Found 585 slices!
# Counting Slices in cine_sax
# Found 1809 slices!
# Counting Slices in aorta_sag
# Found 1191 slices!
# Counting Slices in aorta_tra
# Found 1202 slices!
# Counting Slices in T1map
# Found 1038 slices!
# Counting Slices in T2map
# Found 1038 slices!
# Counting Slices in tagging
# Found 1570 slices!

# %%
all_contrast_full_no_pad = AllContrastDataset(
                '/home/kadotab/scratch/MICCAIChallenge2024/ChallengeData/MultiCoil/', 
                train=True,
                task_one=False,
                transforms=Compose([NormalizeKSpace()])
                )
# Out:
# Counting Slices in cine_lvot
# Found 193 slices!
# Counting Slices in cine_lax
# Found 585 slices!
# Counting Slices in cine_sax
# Found 1809 slices!
# Counting Slices in aorta_sag
# Found 1191 slices!
# Counting Slices in aorta_tra
# Found 1202 slices!
# Counting Slices in T1map
# Found 1038 slices!
# Counting Slices in T2map
# Found 1038 slices!
# Counting Slices in tagging
# Found 1570 slices!

# %%
data_module.setup('train')

# %%
train_dataset = data_module.train_dataloader()

# %%
data = next(iter(train_dataset))

# %%
import matplotlib.pyplot as plt

# %%
us, fs, sense = data

# %%
from torchvision.utils import make_grid
import numpy as np

# %%
plt.imshow(np.abs(sense[0, 0, 0, :, :]))

# %%
us, fs, sense = all_contrast_full[0]
us, fs, sense_2 = all_contrast_full_no_pad[0]

# %%
fig, ax = plt.subplots(3, 2)
ax[0, 0].imshow(np.abs(sense[ 0, 0, :, :]))
ax[1, 0].imshow(np.real(sense[ 0, 0, :, :]))
ax[2, 0].imshow(np.imag(sense[ 0, 0, :, :]))
ax[0, 1].imshow(np.abs(sense_2[ 0, 0, :, :]))
ax[1, 1].imshow(np.real(sense_2[ 0, 0, :, :]))
ax[2, 1].imshow(np.imag(sense_2[ 0, 0, :, :]))
